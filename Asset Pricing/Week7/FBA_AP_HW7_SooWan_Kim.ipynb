# %% [markdown]
# # FBA QUANT AP HW7
# Kim Soo Wan(hse07088@snu.ac.kr)

# %% [markdown]
# ***
# ## Problem 1
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# sol)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## Problem 2
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# sol)
#
# ![image.png](attachment:image.png)
